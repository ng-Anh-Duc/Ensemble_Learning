# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib
from sklearn import tree

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Salary_Data_simple.csv')
df
# Out:
#     Experience  Salary
# 0          1.0     0.0
# 1          1.5     0.0
# 2          2.0     0.0
# 3          2.5     0.0
# 4          3.0    60.0
# 5          3.5    64.0
# 6          4.0    55.0
# 7          4.5    61.0
# 8          5.0    66.0
# 9          5.5    83.0
# 10         6.0    93.0
# 11         6.5    91.0
# 12         7.0    98.0
# 13         7.5   101.0

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=4)
dt_regressor = RandomForestRegressor(n_estimators=3, max_depth=2)
dt_regressor.fit(X, y)
# Out:
# RandomForestRegressor(max_depth=2, n_estimators=3)

# %%
y_pred = dt_regressor.predict(X_test)
print(y_test)
y_pred
# Out:
# 4    60.0
# 3     0.0
# Name: Salary, dtype: float64
# array([38.88888889,  0.        ])

# %%
plt.figure(figsize=(6,6))
_ = tree.plot_tree(dt_regressor.estimators_[0], feature_names=['Experience'], filled=True)

# %%
plt.figure(figsize=(6,6))
_ = tree.plot_tree(dt_regressor.estimators_[1], feature_names=['Experience'], filled=True)

# %%
plt.figure(figsize=(6,6))
_ = tree.plot_tree(dt_regressor.estimators_[2], feature_names=['Experience'], filled=True)
